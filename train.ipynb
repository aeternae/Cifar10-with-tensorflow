# %%
# !python Vgg19.py
# Out:
# Using TensorFlow backend.
# 2019-07-31 10:44:10.073462: I tensorflow/core/platform/cpu_feature_guard.cc:140] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2019-07-31 10:44:10.391081: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1356] Found device 0 with properties:
# name: Tesla T4 major: 7 minor: 5 memoryClockRate(GHz): 1.59
# pciBusID: 0000:0e:00.0
# totalMemory: 14.73GiB freeMemory: 9.89GiB
# 2019-07-31 10:44:10.391160: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1435] Adding visible gpu devices: 0
# 2019-07-31 10:44:10.751066: I tensorflow/core/common_runtime/gpu/gpu_device.cc:923] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2019-07-31 10:44:10.751143: I tensorflow/core/common_runtime/gpu/gpu_device.cc:929]      0
# 2019-07-31 10:44:10.751159: I tensorflow/core/common_runtime/gpu/gpu_device.cc:942] 0:   N
# ...
